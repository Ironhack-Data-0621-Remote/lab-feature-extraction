# %% [markdown]
# # Lab | Cleaning numerical data

# %% [markdown]
# For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder.

# %% [markdown]
# ### 1. Import the necessary libraries.

# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.

# %%
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %% [markdown]
# ### 3. First look at its main features (head, shape, info).

# %%
data.shape
# Out:
# (9134, 24)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %% [markdown]
# ### 4. Rename the columns so they follow the PE8 (snake case).

# %%
data.columns = [columns.lower().replace(' ', '_') for columns in data.columns]
list(data.columns)
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'total_claim_amount',
#  'vehicle_class',
#  'vehicle_size']

# %% [markdown]
# ### 5. Change effective to date column to datetime format.

# %%
data['effective_to_date'] = pd.to_datetime(data['effective_to_date'])

# extract the month and year and make new columns
data['effective_month'] = data['effective_to_date'].dt.strftime('%m')
data['effective_year'] = data['effective_to_date'].dt.strftime('%Y')
data
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  \
# ...

# %% [markdown]
# ### 6. Check NaN values per column.

# %%
nulls = pd.DataFrame(data.isna().sum()*100/len(data), columns=['percentage'])
nulls.sort_values('percentage', ascending = False)
# Out:
#                                percentage
# customer                              0.0
# state                                 0.0
# effective_month                       0.0
# vehicle_size                          0.0
# vehicle_class                         0.0
# total_claim_amount                    0.0
# sales_channel                         0.0
# renew_offer_type                      0.0
# policy                                0.0
# policy_type                           0.0
# number_of_policies                    0.0
# number_of_open_complaints             0.0
# months_since_policy_inception         0.0
# months_since_last_claim               0.0
# monthly_premium_auto                  0.0
# marital_status                        0.0
# location_code                         0.0
# income                                0.0
# gender                                0.0
# employmentstatus                      0.0
# effective_to_date                     0.0
# ...

# %% [markdown]
# ### 7. Define a function that differentiates between continuous and discrete variables. Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
data.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
data.dtypes['customer']
# Out:
# dtype('O')

# %%
def check(data):
    
    # if the column's data.dtype == 'float' --> continuous
    
    c = data.columns
    continuous = []
    discrete = []
    categorical = []
    
    for i in c:
        if data.dtypes[i] == float:
            continuous.append(i)  #str
    
    #elif the column's data.dtype == 'int' --> discrete
    
        elif data.dtypes[i] == int:
            discrete.append(i)
    
        
    #else: categorical
    
        else:
            
            categorical.append(i)
    
    return continuous, discrete, categorical

# %%
check(data)
# Out:
# (['customer_lifetime_value', 'total_claim_amount'],
#  ['income',
#   'monthly_premium_auto',
#   'months_since_last_claim',
#   'months_since_policy_inception',
#   'number_of_open_complaints',
#   'number_of_policies'],
#  ['customer',
#   'state',
#   'response',
#   'coverage',
#   'education',
#   'effective_to_date',
#   'employmentstatus',
#   'gender',
#   'location_code',
#   'marital_status',
#   'policy_type',
#   'policy',
#   'renew_offer_type',
#   'sales_channel',
#   'vehicle_class',
#   'vehicle_size',
#   'effective_month',
#   'effective_year'])

# %% [markdown]
# ### 8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it. Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.

# %%
data_cat = data.select_dtypes('object')
data_cat
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %%
data['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: vehicle_class, dtype: int64

# %%
# now try to change the sports car, lux suv, lux car to 'Others'

data['vehicle_class'] = data['vehicle_class'].apply(lambda x: x if x in ['Four-Door Car', 'Two-Door Car', 'SUV'] else 'others')
data['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# others            831
# Name: vehicle_class, dtype: int64

# %% [markdown]
# ### 9. Get categorical features.

# %%
data_cat
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %% [markdown]
# ### 10. What should we do with the customer_id column?

# %% [markdown]
# Customer_id is a unique value so there are 2 option
# 1. drop
# 2. change into INDEX

# %%
data = data.set_index('customer')
data
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
# ...

# %% [markdown]
# # Lab | Feature extraction

# %% [markdown]
# ### 1. Open the categoricals variable we created before.

# %%
categoricals = data.select_dtypes(np.object)
categoricals.head()
# Out:
#                state response  coverage education employmentstatus gender  \
# customer
# BU79786   Washington       No     Basic  Bachelor         Employed      F
# QZ44356      Arizona       No  Extended  Bachelor       Unemployed      F
# AI49188       Nevada       No   Premium  Bachelor         Employed      F
# WW63253   California       No     Basic  Bachelor       Unemployed      M
# HB64268   Washington       No     Basic  Bachelor         Employed      M
#
#          location_code marital_status     policy_type        policy  \
# customer
# BU79786       Suburban        Married  Corporate Auto  Corporate L3
# QZ44356       Suburban         Single   Personal Auto   Personal L3
# AI49188       Suburban        Married   Personal Auto   Personal L3
# WW63253       Suburban        Married  Corporate Auto  Corporate L2
# HB64268          Rural         Single   Personal Auto   Personal L1
#
#          renew_offer_type sales_channel  vehicle_class vehicle_size  \
# customer
# ...

# %% [markdown]
# ### 2. Plot all the categorical variables with the proper plot. What can you see?

# %%
# countplot on seaborn
for column in categoricals.columns:
    sns.countplot(column, data = categoricals, color = 'skyblue')
    plt.show()

# %% [markdown]
# Findings:
# - Most customers are located in California and Oregon
# - Majority of the customers have basic package
# - Majority have Bachelor degree or college degree
# - Majority are employed customer
# - Majority are living in Suburban areas
# - Majority have Personal Auto Policy Type
# - The highest sales channel is via agent and at the branch
# - Four-Door car are owned the highest
# - Mid-size vehicles are best sold

# %% [markdown]
# ### Also check multiple categorical variables to see the relationship
#
# #### State & education
# Findings:
# Washinton and Nevada state has more 'High School or Below' than college or university degree.
# In contrast, California and Oregon has higher amount of customer with college for bachelor degree.

# %%
sns.countplot('state', hue = 'education', palette = 'rainbow', data = categoricals)
# Out:
# <AxesSubplot:xlabel='state', ylabel='count'>

# %% [markdown]
# #### Coverage and employment_status
# Findings: large number os employed status customers are owning the cars. interesting finding is that  disabled customer are tend to buy premium package.

# %%
sns.countplot(y= 'coverage', hue = 'employmentstatus', palette = 'rainbow',  data = categoricals)
# Out:
# <AxesSubplot:xlabel='count', ylabel='coverage'>

# %% [markdown]
# #### State and Location_code
# Findings: most customers are living in suburban areas in all states, therefore targeting suburban is all states are important.

# %%
sns.countplot(y='state', hue = 'location_code',palette = 'rainbow', order =categoricals.state.value_counts().index,  data = categoricals)
# Out:
# <AxesSubplot:xlabel='count', ylabel='state'>

# %% [markdown]
# #### state and vehicle class

# %%
sns.countplot(y='state', hue = 'vehicle_class',palette = 'rainbow', order =categoricals.state.value_counts().index,  data = categoricals)
# Out:
# <AxesSubplot:xlabel='count', ylabel='state'>

# %%
categoricals.state.value_counts().index
# Out:
# Index(['California', 'Oregon', 'Arizona', 'Nevada', 'Washington'], dtype='object')

# %% [markdown]
# ### 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %%
categoricals.head()
# Out:
#                state response  coverage education employmentstatus gender  \
# customer
# BU79786   Washington       No     Basic  Bachelor         Employed      F
# QZ44356      Arizona       No  Extended  Bachelor       Unemployed      F
# AI49188       Nevada       No   Premium  Bachelor         Employed      F
# WW63253   California       No     Basic  Bachelor       Unemployed      M
# HB64268   Washington       No     Basic  Bachelor         Employed      M
#
#          location_code marital_status     policy_type        policy  \
# customer
# BU79786       Suburban        Married  Corporate Auto  Corporate L3
# QZ44356       Suburban         Single   Personal Auto   Personal L3
# AI49188       Suburban        Married   Personal Auto   Personal L3
# WW63253       Suburban        Married  Corporate Auto  Corporate L2
# HB64268          Rural         Single   Personal Auto   Personal L1
#
#          renew_offer_type sales_channel  vehicle_class vehicle_size  \
# customer
# ...

# %%
for col in categoricals:
    print(categoricals[col].value_counts(), '\n')
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
#
# F    4658
# M    4476
# Name: gender, dtype: int64
#
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
#
# Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
#
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64
#
# ...

# %%
word = 'Personal L3'

# %%
word_1 = word[:-3]
word_1
# Out:
# 'Personal'

# %% [markdown]
# #### The column 'policy_type' and 'policy' is redundant. Therefore, 'policy_type' can be dropped. In addition, the policy column can be separated into two columns.

# %%
def cleaner():
    
    #col = categoricals['policy']
    
    new_col = []
    
    for i in col:
        new_value = i[-2:]
        new_col.append(new_value)
    
    return new_col

# %%
# test if the funtion is working
#separator(['hello L2', 'goodnight L4', 'hellohello L7'])

# %%
#make a new column 'policy_level' with last 2 letters of 'policy'.

categoricals['policy_level'] = categoricals['policy'].apply(lambda x: x[-2:])
categoricals['policy_level']
# Out:
# customer
# BU79786    L3
# QZ44356    L3
# AI49188    L3
# WW63253    L2
# HB64268    L1
#            ..
# LA72316    L1
# PK87824    L3
# TD14365    L2
# UP19263    L2
# Y167826    L3
# Name: policy_level, Length: 9134, dtype: object

# %%
# remove the last 2 letter from policy
categoricals['policy'] = categoricals['policy'].apply(lambda x: x[:-3])
categoricals['policy']
# Out:
# customer
# BU79786    Corporate
# QZ44356     Personal
# AI49188     Personal
# WW63253    Corporate
# HB64268     Personal
#              ...
# LA72316     Personal
# PK87824    Corporate
# TD14365    Corporate
# UP19263     Personal
# Y167826    Corporate
# Name: policy, Length: 9134, dtype: object

# %%
# finally, drop the column 'policy_type'
categoricals = categoricals.drop(['policy_type'], axis = 1)

# %% [markdown]
# ### 4. Plot time variable. Can you extract something from it?

# %%
data1 = data.filter(['effective_to_date', 'number_of_open_complaints'], axis=1)
data1
# Out:
#          effective_to_date  number_of_open_complaints
# customer
# BU79786         2011-02-24                          0
# QZ44356         2011-01-31                          0
# AI49188         2011-02-19                          0
# WW63253         2011-01-20                          0
# HB64268         2011-02-03                          0
# ...                    ...                        ...
# LA72316         2011-02-10                          0
# PK87824         2011-02-12                          0
# TD14365         2011-02-06                          3
# UP19263         2011-02-03                          0
# Y167826         2011-02-14                          0
#
# [9134 rows x 2 columns]

# %%
import datetime
plt.figure(figsize = (20,16))
data1.plot('effective_to_date', 'number_of_open_complaints')
# Out:
# <AxesSubplot:xlabel='effective_to_date'>

# %%
plt.figure(figsize=(20,20))
plt.scatter(data1['effective_to_date'], data1['number_of_open_complaints'])
plt.show()

# %%
plt.figure(figsize=(16,8))

sns.barplot(x="effective_to_date", y="number_of_open_complaints", data=data1)
plt.show()

# %% [markdown]
# ### Questions:
#
# I dont know how to plot time. are there any suitable ones...?
